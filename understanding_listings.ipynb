# %%
import pandas as pd
import io
import csv

# %%
# this code is highly useful to peek into large csv files and getting header column without reading entire file.
all_cols = []
fp = open("Drive/Combined Listing Data [Detailed].csv", "rb")
buffered = io.BufferedReader(fp, buffer_size=4096)
decoded = io.TextIOWrapper(buffered, encoding="utf-8")
reader = csv.reader(decoded)
all_cols = reader.__next__()
len(all_cols)
# Out:
# 109

# %%
all_cols
# Out:
# ['',
#  'id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'reviews_per_month',
#  'access',
#  'interaction',
#  'house_rules',
#  'is_business_travel_ready',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'number_of_reviews_ltm',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'number_of_reviews_l30d',
#  'bathrooms_text']

# %%
df = pd.DataFrame(columns=all_cols)
for i in range(0,10):
    row = reader.__next__()
    temp_df = pd.DataFrame(row).T
    temp_df.columns = all_cols
    df = pd.concat([df,temp_df])
buffered.close()
fp.close()
df.reset_index(drop=True)
df.head()
# Out:
#            id                           listing_url       scrape_id  \
# 0  0   986942   https://www.airbnb.com/rooms/986942  20150902161235
# 0  1  3249753  https://www.airbnb.com/rooms/3249753  20150902161235
# 0  2  3250095  https://www.airbnb.com/rooms/3250095  20150902161235
# 0  3  3250595  https://www.airbnb.com/rooms/3250595  20150902161235
# 0  4  1941493  https://www.airbnb.com/rooms/1941493  20150902161235
#
#   last_scraped                                 name  \
# 0   2015-09-02    Attic in Echo Park Hillside House
# 0   2015-09-03   Art BNB @ Nomad Printmaking Studio
# 0   2015-09-03  Art BNB @ nomaD Printmaking Studio
# 0   2015-09-03   Art BNB @ nomAd Printmaking Studio
# 0   2015-09-03    1915 L.A. River Retreat - Two Bed
#
#                                              summary  \
# 0
# 0  Our Punk Shui industrial art space has cool, c...
# 0  Our Punk Shui industrial art space has cool, c...
# 0  Our Punk Shui industrial art space has cool, c...
# 0  Enjoy city & mountain views from the upper uni...
#
#                                                space  \
# 0  Hi Travelers! We have a sweet, spacious attic ...
# 0  We have been in this space for 6 years operati...
# 0  We have been in this space for 6 years operati...
# 0  We have been in this space for 6 years operati...
# 0  If you like old, well-crafted things, this 191...
#
#                                          description experiences_offered  ...  \
# 0  Hi Travelers! We have a sweet, spacious attic ...                none  ...
# 0  Our Punk Shui industrial art space has cool, c...                none  ...
# 0  Our Punk Shui industrial art space has cool, c...                none  ...
# 0  Our Punk Shui industrial art space has cool, c...                none  ...
# 0  Enjoy city & mountain views from the upper uni...                none  ...
#
#   minimum_maximum_nights maximum_maximum_nights minimum_nights_avg_ntm  \
# 0
# 0
# 0
# 0
# 0
#
#   maximum_nights_avg_ntm number_of_reviews_ltm  \
# 0
# 0
# 0
# 0
# 0
#
#   calculated_host_listings_count_entire_homes  \
# 0
# 0
# 0
# 0
# 0
#
#   calculated_host_listings_count_private_rooms  \
# 0
# 0
# 0
# 0
# 0
#
#   calculated_host_listings_count_shared_rooms number_of_reviews_l30d  \
# 0
# 0
# 0
# 0
# 0
#
#   bathrooms_text
# 0
# 0
# 0
# 0
# 0
#
# [5 rows x 109 columns]

# %%
monthly_listing_df = pd.read_csv("Drive/Data Files [Detailed] 2/los_angeles_2015_09_listings.csv.gz")
monthly_listing_df.head()
# Out:
# /var/folders/lx/wx3109f56_50_r0_22hgbcjr0000gn/T/ipykernel_55190/1660391875.py:1: DtypeWarning: Columns (40,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   monthly_listing_df = pd.read_csv("Drive/Data Files [Detailed] 2/los_angeles_2015_09_listings.csv.gz")
#         id                           listing_url       scrape_id last_scraped  \
# 0   986942   https://www.airbnb.com/rooms/986942  20150902161235   2015-09-02
# 1  3249753  https://www.airbnb.com/rooms/3249753  20150902161235   2015-09-03
# 2  3250095  https://www.airbnb.com/rooms/3250095  20150902161235   2015-09-03
# 3  3250595  https://www.airbnb.com/rooms/3250595  20150902161235   2015-09-03
# 4  1941493  https://www.airbnb.com/rooms/1941493  20150902161235   2015-09-03
#
#                                   name  \
# 0    Attic in Echo Park Hillside House
# 1   Art BNB @ Nomad Printmaking Studio
# 2  Art BNB @ nomaD Printmaking Studio
# 3   Art BNB @ nomAd Printmaking Studio
# 4    1915 L.A. River Retreat - Two Bed
#
#                                              summary  \
# 0                                                NaN
# 1  Our Punk Shui industrial art space has cool, c...
# 2  Our Punk Shui industrial art space has cool, c...
# 3  Our Punk Shui industrial art space has cool, c...
# 4  Enjoy city & mountain views from the upper uni...
#
#                                                space  \
# 0  Hi Travelers! We have a sweet, spacious attic ...
# 1  We have been in this space for 6 years operati...
# 2  We have been in this space for 6 years operati...
# 3  We have been in this space for 6 years operati...
# 4  If you like old, well-crafted things, this 191...
#
#                                          description experiences_offered  \
# 0  Hi Travelers! We have a sweet, spacious attic ...                none
# 1  Our Punk Shui industrial art space has cool, c...                none
# 2  Our Punk Shui industrial art space has cool, c...                none
# 3  Our Punk Shui industrial art space has cool, c...                none
# 4  Enjoy city & mountain views from the upper uni...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0                                                NaN  ...                 9.0
# 1  We are in the center of LA's most creative, fo...  ...                10.0
# 2  We are in the center of LA's most creative, fo...  ...                 8.0
# 3  We are in the center of LA's most creative, fo...  ...                 NaN
# 4  This neighborhood is in a state of rapid, exci...  ...                 9.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                f
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy  require_guest_profile_picture  \
# 0            moderate                              f
# 1            flexible                              f
# 2            flexible                              f
# 3            flexible                              f
# 4              strict                              f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              3
# 1                                f                              5
# 2                                f                              5
# 3                                f                              5
# 4                                f                              1
#
#   reviews_per_month
# 0              0.63
# 1              0.13
# 2              0.07
# 3               NaN
# 4              1.57
#
# [5 rows x 92 columns]
